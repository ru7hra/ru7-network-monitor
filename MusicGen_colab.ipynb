# %% [markdown]
# <a href="https://colab.research.google.com/github/ru7hra/ru7-network-monitor/blob/main/MusicGen_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b v1.0 https://github.com/camenduru/audiocraft
# %cd /content/audiocraft
# !pip install -r requirements.txt
# !python app.py --share
# Out:
# /content
# Cloning into 'audiocraft'...
# remote: Enumerating objects: 960, done.
# remote: Counting objects: 100% (206/206), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 960 (delta 132), reused 107 (delta 95), pack-reused 754
# Receiving objects: 100% (960/960), 1.63 MiB | 16.03 MiB/s, done.
# Resolving deltas: 100% (500/500), done.
# /content/audiocraft
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.0/31.0 MB 46.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 kB 9.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
